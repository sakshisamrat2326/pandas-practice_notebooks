# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h5 style="color:#2c3e50; font-size:48px;">📊 1)Finding Missing Data</h5>

# %%
import pandas as pd
import numpy as np

# Sample dataset with np.nan
data = {
    "Name": ["Sakshi", "Aman", "Riya", "Karan", "Neha"],
    "Age": [23, np.nan, 21, 24, np.nan],
    "Department": ["IT", "HR", np.nan, "Finance", "IT"],
    "Salary": [50000, 45000, np.nan, 60000, 52000]
}

df = pd.DataFrame(data)
df
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
df.isna() #Nan value=true , other given values=false
# Out:
#     Name    Age  Department  Salary
# 0  False  False       False   False
# 1  False   True       False   False
# 2  False  False        True    True
# 3  False  False       False   False
# 4  False   True       False   False

# %%
df.isna().sum() #count of Na values in each row
# Out:
# Name          0
# Age           2
# Department    1
# Salary        1
# dtype: int64

# %%
df.isna().any() # => any row that has no nan value is false
# Out:
# Name          False
# Age            True
# Department     True
# Salary         True
# dtype: bool

# %% [markdown]
# <h5 style="color:#2c3e50; font-size:48px;">📊2) Removing Missing Data</h5>

# %% [markdown]
# => works on basis pf rows

# %%
df
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
df.dropna()
#➡ Removes all rows that contain at least one NaN.
# rowwise
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 3   Karan  24.0    Finance  60000.0

# %%
df
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
df.dropna(thresh=3)   #➡Keeps rows with at least 3 non-null values.
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
df.dropna(thresh=4)
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 3   Karan  24.0    Finance  60000.0

# %%
df.dropna(thresh=5)
# Out:
# Empty DataFrame
# Columns: [Name, Age, Department, Salary]
# Index: []

# %% [markdown]
# <h5 style="color:#2c3e50; font-size:48px;">📊3)Filling Missing Data</h5>
# => fill NaN values

# %%
df
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
df.fillna(0) 
#=> column vise
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   0.0         HR  45000.0
# 2    Riya  21.0          0      0.0
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   0.0         IT  52000.0

# %%
df #=> still df is not changed coz inplace isn't true (inplace=true)
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
values={'Name':0,'Age':1,'Department':2,'Salary':3}
df.fillna(value=values)
#each column diff values filling
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   1.0         HR  45000.0
# 2    Riya  21.0          2      3.0
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   1.0         IT  52000.0

# %%
df
# Out:
#      Name   Age Department   Salary
# 0  Sakshi  23.0         IT  50000.0
# 1    Aman   NaN         HR  45000.0
# 2    Riya  21.0        NaN      NaN
# 3   Karan  24.0    Finance  60000.0
# 4    Neha   NaN         IT  52000.0

# %%
# df.fillna(df.mean()) => only works for numeric values
df.fillna(df.mean(numeric_only=True)) #=> for mixed value
# Out:
#      Name        Age Department   Salary
# 0  Sakshi  23.000000         IT  50000.0
# 1    Aman  22.666667         HR  45000.0
# 2    Riya  21.000000        NaN  51750.0
# 3   Karan  24.000000    Finance  60000.0
# 4    Neha  22.666667         IT  52000.0
